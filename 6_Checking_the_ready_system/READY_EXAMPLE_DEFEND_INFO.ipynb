# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install pillow
# Out:
# ...
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-ob_8bxc0
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-ob_8bxc0
# ...
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101066 sha256=a37f59c6ec25b84e6874a69f66ea60f18d2663800677ac899d75ed165acb7b29
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i8ezu3f4/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive/')
root_dir = '/content/drive/My Drive/Colab Notebooks/'


path_to_generator = "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist/models/model_generator.h5"
path_to_classificator = "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/my_model.h5"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from __future__ import print_function, division
import scipy
from scipy import misc
import imageio
from keras.datasets import mnist
import keras_contrib
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
import datetime
import matplotlib.pyplot as plt
import sys
import numpy as np
import os
from skimage.transform import resize
from PIL import Image

from glob import glob

# %%
from keras import backend as keras_backend
import seaborn as sns
sns.set(style="darkgrid")
from keras.models import load_model

# %%
generator = load_model(path_to_generator, custom_objects = {'InstanceNormalization': keras_contrib.layers.normalization.instancenormalization.InstanceNormalization}, compile=False)
classificator = load_model(path_to_classificator)

# %%
img_rows = 32
img_cols = 32
img_colors = 3

# ============================================================================================================

# Пропускаем через генератор


path = '/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/0_1.jpg'
img = Image.open(path)
img = img.convert('RGB')
#img = img.resize((img_rows,img_cols))
img = np.array(img)
img = np.array(img)/127.5 - 1.
img = img.reshape(1,img_rows*4, img_cols*4, img_colors)

fake_img = generator.predict(img)
fake_img = np.reshape(fake_img, (img_rows*4, img_cols*4, img_colors))
img_to_save = fake_img * 255
img_to_save = img_to_save.astype(np.uint8)
img_to_save = Image.fromarray(img_to_save)
img_to_save = img_to_save.resize((img_rows, img_cols))
img_to_save.save( "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/0_1.png" )


import cv2
image_name = '0_1.png'
imgorig = cv2.imread('/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/' + image_name, cv2.IMREAD_COLOR)
rgb_img = cv2.cvtColor(imgorig, cv2.COLOR_BGR2RGB) # Это и есть одна выборка

# Даем ему форму Tensor-4D (т.к. функция predict() нашей натренированной модели принимает именно его на вход)
rgb_img = rgb_img.reshape(1,img_rows, img_cols, img_colors)

# Проверяем размерность
print(rgb_img.shape)

# Производим ту же самую предобработку, что и с тренировочным набором
rgb_img = keras_backend.cast_to_floatx(rgb_img)
rgb_img = np.interp(rgb_img, [0,255], [-1,1])

test_our_image = classificator.predict_classes(rgb_img,verbose = 1)
print('Our predict on (0_1.png). Исходное изображение ("0_1.jpg") = ', test_our_image[0])
# ============================================================================================================





# ============================================================================================================

# Пропускаем через генератор


path = '/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/0_2.jpg'
img = Image.open(path)
img = img.convert('RGB')
#img = img.resize((img_rows,img_cols))
img = np.array(img)
img = np.array(img)/127.5 - 1.
img = img.reshape(1,img_rows*4, img_cols*4, img_colors)

fake_img = generator.predict(img)
fake_img = np.reshape(fake_img, (img_rows*4, img_cols*4, img_colors))
img_to_save = fake_img * 255
img_to_save = img_to_save.astype(np.uint8)
img_to_save = Image.fromarray(img_to_save)
img_to_save = img_to_save.resize((img_rows, img_cols))
img_to_save.save( "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/0_2.png" )


import cv2
image_name = '0_2.png'
imgorig = cv2.imread('/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/' + image_name, cv2.IMREAD_COLOR)
rgb_img = cv2.cvtColor(imgorig, cv2.COLOR_BGR2RGB) # Это и есть одна выборка

# Даем ему форму Tensor-4D (т.к. функция predict() нашей натренированной модели принимает именно его на вход)
rgb_img = rgb_img.reshape(1,img_rows, img_cols, img_colors)

# Проверяем размерность
print(rgb_img.shape)

# Производим ту же самую предобработку, что и с тренировочным набором
rgb_img = keras_backend.cast_to_floatx(rgb_img)
rgb_img = np.interp(rgb_img, [0,255], [-1,1])

test_our_image = classificator.predict_classes(rgb_img,verbose = 1)
print('Our predict on (0_2.png). Исходное изображение ("0_2.jpg") = ', test_our_image[0])
# ============================================================================================================





# ============================================================================================================

# Пропускаем через генератор


path = '/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/0_3.jpg'
img = Image.open(path)
img = img.convert('RGB')
#img = img.resize((img_rows,img_cols))
img = np.array(img)
img = np.array(img)/127.5 - 1.
img = img.reshape(1,img_rows*4, img_cols*4, img_colors)

fake_img = generator.predict(img)
fake_img = np.reshape(fake_img, (img_rows*4, img_cols*4, img_colors))
img_to_save = fake_img * 255
img_to_save = img_to_save.astype(np.uint8)
img_to_save = Image.fromarray(img_to_save)
img_to_save = img_to_save.resize((img_rows, img_cols))
img_to_save.save( "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/0_3.png" )


import cv2
image_name = '0_3.png'
imgorig = cv2.imread('/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/' + image_name, cv2.IMREAD_COLOR)
rgb_img = cv2.cvtColor(imgorig, cv2.COLOR_BGR2RGB) # Это и есть одна выборка

# Даем ему форму Tensor-4D (т.к. функция predict() нашей натренированной модели принимает именно его на вход)
rgb_img = rgb_img.reshape(1,img_rows, img_cols, img_colors)

# Проверяем размерность
print(rgb_img.shape)

# Производим ту же самую предобработку, что и с тренировочным набором
rgb_img = keras_backend.cast_to_floatx(rgb_img)
rgb_img = np.interp(rgb_img, [0,255], [-1,1])

test_our_image = classificator.predict_classes(rgb_img,verbose = 1)
print('Our predict on (0_3.png). Исходное изображение ("0_3.jpg") = ', test_our_image[0])
# ============================================================================================================




# ============================================================================================================

# Пропускаем через генератор


path = '/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/1_1.jpg'
img = Image.open(path)
img = img.convert('RGB')
#img = img.resize((img_rows,img_cols))
img = np.array(img)
img = np.array(img)/127.5 - 1.
img = img.reshape(1,img_rows*4, img_cols*4, img_colors)

fake_img = generator.predict(img)
fake_img = np.reshape(fake_img, (img_rows*4, img_cols*4, img_colors))
img_to_save = fake_img * 255
img_to_save = img_to_save.astype(np.uint8)
img_to_save = Image.fromarray(img_to_save)
img_to_save = img_to_save.resize((img_rows, img_cols))
img_to_save.save( "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/1_1.png" )


import cv2
image_name = '1_1.png'
imgorig = cv2.imread('/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/' + image_name, cv2.IMREAD_COLOR)
rgb_img = cv2.cvtColor(imgorig, cv2.COLOR_BGR2RGB) # Это и есть одна выборка

# Даем ему форму Tensor-4D (т.к. функция predict() нашей натренированной модели принимает именно его на вход)
rgb_img = rgb_img.reshape(1,img_rows, img_cols, img_colors)

# Проверяем размерность
print(rgb_img.shape)

# Производим ту же самую предобработку, что и с тренировочным набором
rgb_img = keras_backend.cast_to_floatx(rgb_img)
rgb_img = np.interp(rgb_img, [0,255], [-1,1])

test_our_image = classificator.predict_classes(rgb_img,verbose = 1)
print('Our predict on (1_1.png). Исходное изображение ("1_1.jpg") = ', test_our_image[0])
# ============================================================================================================







# ============================================================================================================

# Пропускаем через генератор


path = '/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/1_2.jpg'
img = Image.open(path)
img = img.convert('RGB')
#img = img.resize((img_rows,img_cols))
img = np.array(img)
img = np.array(img)/127.5 - 1.
img = img.reshape(1,img_rows*4, img_cols*4, img_colors)

fake_img = generator.predict(img)
fake_img = np.reshape(fake_img, (img_rows*4, img_cols*4, img_colors))
img_to_save = fake_img * 255
img_to_save = img_to_save.astype(np.uint8)
img_to_save = Image.fromarray(img_to_save)
img_to_save = img_to_save.resize((img_rows, img_cols))
img_to_save.save( "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/1_2.png" )


import cv2
image_name = '1_2.png'
imgorig = cv2.imread('/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/' + image_name, cv2.IMREAD_COLOR)
rgb_img = cv2.cvtColor(imgorig, cv2.COLOR_BGR2RGB) # Это и есть одна выборка

# Даем ему форму Tensor-4D (т.к. функция predict() нашей натренированной модели принимает именно его на вход)
rgb_img = rgb_img.reshape(1,img_rows, img_cols, img_colors)

# Проверяем размерность
print(rgb_img.shape)

# Производим ту же самую предобработку, что и с тренировочным набором
rgb_img = keras_backend.cast_to_floatx(rgb_img)
rgb_img = np.interp(rgb_img, [0,255], [-1,1])

test_our_image = classificator.predict_classes(rgb_img,verbose = 1)
print('Our predict on (1_2.png). Исходное изображение ("1_2.jpg") = ', test_our_image[0])
# ============================================================================================================




# ============================================================================================================

# Пропускаем через генератор


path = '/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/1_3.jpg'
img = Image.open(path)
img = img.convert('RGB')
#img = img.resize((img_rows,img_cols))
img = np.array(img)
img = np.array(img)/127.5 - 1.
img = img.reshape(1,img_rows*4, img_cols*4, img_colors)

fake_img = generator.predict(img)
fake_img = np.reshape(fake_img, (img_rows*4, img_cols*4, img_colors))
img_to_save = fake_img * 255
img_to_save = img_to_save.astype(np.uint8)
img_to_save = Image.fromarray(img_to_save)
img_to_save = img_to_save.resize((img_rows, img_cols))
img_to_save.save( "/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/1_3.png" )


import cv2
image_name = '1_3.png'
imgorig = cv2.imread('/content/drive/My Drive/Colab Notebooks/datasets/turn_mnist_gen/128_128/' + image_name, cv2.IMREAD_COLOR)
rgb_img = cv2.cvtColor(imgorig, cv2.COLOR_BGR2RGB) # Это и есть одна выборка

# Даем ему форму Tensor-4D (т.к. функция predict() нашей натренированной модели принимает именно его на вход)
rgb_img = rgb_img.reshape(1,img_rows, img_cols, img_colors)

# Проверяем размерность
print(rgb_img.shape)

# Производим ту же самую предобработку, что и с тренировочным набором
rgb_img = keras_backend.cast_to_floatx(rgb_img)
rgb_img = np.interp(rgb_img, [0,255], [-1,1])

test_our_image = classificator.predict_classes(rgb_img,verbose = 1)
print('Our predict on (1_3.png). Исходное изображение ("1_3.jpg") = ', test_our_image[0])
# ============================================================================================================
# Out:
# (1, 32, 32, 3)
# WARNING:tensorflow:From <ipython-input-6-30b1c7eda998>:42: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# 1/1 [==============================] - 0s 2ms/step
# Our predict on (0_1.png). Исходное изображение ("0_1.jpg") =  0
# (1, 32, 32, 3)
# 1/1 [==============================] - 0s 3ms/step
# Our predict on (0_2.png). Исходное изображение ("0_2.jpg") =  0
# (1, 32, 32, 3)
# 1/1 [==============================] - 0s 2ms/step
# Our predict on (0_3.png). Исходное изображение ("0_3.jpg") =  0
# (1, 32, 32, 3)
# ...

# %%
print("Работа программы завершена.")
# Out:
# Работа программы завершена.
